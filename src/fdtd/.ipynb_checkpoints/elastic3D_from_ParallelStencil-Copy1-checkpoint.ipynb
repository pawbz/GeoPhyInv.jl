# %%
## Load some packages
using Revise # for testing diff packages (ignore)
using ParallelStencil # Finite differences using GPUs
using GeoPhyInv # for elastic wave eq. solver

using ProgressMeter
# using Distributed
# using DistributedArrays
# using CUDA
# using NamedArrays
# using OrderedCollections
using Plots
# Printf, Statistics


# initiate a 3D solver, either Float64, Float32
GeoPhyInv.@init_parallel_stencil(CUDA, Float64, 3)
#     @init_parallel_stencil(Threads, Float64, 3)
# plotly()
gr()
# Out:
# ┌ Info: Precompiling ParallelStencil [94395366-693c-11ea-3b26-d9b7aac5d958]
# └ @ Base loading.jl:1317
# ┌ Info: Precompiling GeoPhyInv [e0ed03db-c84c-5109-9210-aed666ad9ba8]
# └ @ Base loading.jl:1317
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1317
# Plots.GRBackend()

# %%
d=5 # sampling interval
# mgrid is a vector with 3 ranges, first range is z, second is y and last is x
mgrid=[range(0.,stop=3000., step=d), range(-1000,step=d,stop=1000), range(0,stop=9000,step=d)]

nz,ny,nx=length.(mgrid); # fetching length
dz,dy,dx=step.(mgrid); # fetching step

medium=Medium(mgrid,[:vp,:rho,:vs]) # initialize (zeros) a seismic medium on mgrid

# choose the bounds
vpb = [3000., 3500.] # bounds for vp ()
vsb = [1900, 2000] # bounds for vs ()
rhob = [1., 2.] # density bounds (kg/m3)

# putting the bounds in medium
GeoPhyInv.update!(medium, [:vp,:vs,:rho], [vpb,vsb,rhob]);

# fill the medium with mean values of the bounds
fill!(medium);

# GeoPhyInv.update!(medium, [:vp,:vs,:rho], randn_perc=5); # add some random noise
# medium

println(medium)
# Out:
# > 3-D Medium with [:z, :y, :x] in [[0.0, 3000.0], [-1000.0, 1000.0], [0.0, 9000.0]]
# > number of samples:	[601, 401, 1801]
# > sampling intervals:	[5.0, 5.0, 5.0]
# > vp:	min	3250.0	max	3250.0
# > vs:	min	1950.0	max	1950.0
# > rho:	min	1.5	max	1.5
# > Bounds:
# 8-element Named Vector{Vector{Float64}}
# vcat  │
# ──────┼─────────────────────────
# :vp   │         [3000.0, 3500.0]
# :rho  │               [1.0, 2.0]
# :vs   │         [1900.0, 2000.0]
# :K    │   [4.18667e6, 1.38333e7]
# :KI   │ [7.22892e-8, 2.38854e-7]
# :rhoI │               [0.5, 1.0]
# :mu   │          [3.61e6, 8.0e6]
# :muI  │    [1.25e-7, 2.77008e-7]

# %%
# medium.mgrid will isolate the grid
# ageom=AGeom(medium.mgrid, SSrcs(1), [Srcs(1), Srcs(2)], [Recs(10), Recs(5)])
# ageom=AGeom(medium.mgrid, :vsp, SSrcs(10), Recs(100)) # surface acquisition
ageom=AGeom(medium.mgrid, :microseismic, SSrcs(1), Recs(100)) # surface acquisition
println(ageom)
# Out:
# > 3-D acquisition with 1 supersource(s), [1] source(s) and [100] receiver(s)

# %%
# look at vp of the medium, slice along y=ymean
# heatmap(medium[:vp][:,div(ny,2),:], yflip=true)
plot(ageom, SSrcs(),yflip=true)
plot!(ageom, Recs())

# %%
# 8 wavelengths along the diagonal of the medium, and total time of 1 diagonal
wav, tgrid=ricker(medium, 8, 1,)
dt=step(tgrid)


freqmax=GeoPhyInv.Utils.findfreq(wav,tgrid,attrib=:max)
freqpeak=GeoPhyInv.Utils.findfreq(wav,tgrid,attrib=:peak)
freqmin=GeoPhyInv.Utils.findfreq(wav,tgrid,attrib=:min)
tmax=maximum(tgrid); nt=length(tgrid); 
print("nt:\t",length(tgrid))
print("freqpeak:\t",freqpeak)



# intialize SrcWavelets
srcwav = SrcWav(tgrid, ageom, [:vx])
GeoPhyInv.update!(srcwav, [:vx], wav)

plot(wav)
# Out:
# nt:	8332freqpeak:	2.681563138505797

# %%
tsnaps=tgrid[1:div(length(tgrid),20):end] # store 20 snapshots
pa = SeisForwExpt(
#     FdtdAcou(),
    FdtdElastic(),
#         snaps_field=:vz,
    tsnaps=tsnaps,
    npw = 1,
    pml_edges=[:xmin, :xmax, :zmax],
    medium = medium,
    ageom = [ageom],
    srcwav = [srcwav],
    rfields= [:vz],
    sflags = [2],
    rflags = [1],
    tgrid = tgrid,
    zfree = 0,
    verbose = true,
);
# Out:
# NamedVector{NamedVector{CuArray{Float64, 1, CUDA.Mem.DeviceBuffer}, Vector{CuArray{Float64, 1, CUDA.Mem.DeviceBuffer}}, Tuple{OrderedDict{Symbol, Int64}}}, Vector{NamedVector{CuArray{Float64, 1, CUDA.Mem.DeviceBuffer}, Vector{CuArray{Float64, 1, CUDA.Mem.DeviceBuffer}}, Tuple{OrderedDict{Symbol, Int64}}}}, Tuple{OrderedDict{Symbol, Int64}}}wefwfr	truefalse
# ┌ Info: frequency bounds for propagating wavefield 1 are: [1.64e-01, 7.23e+00], with peak at: 1.81e+00
# └ @ GeoPhyInv /home/pawan/.julia/dev/GeoPhyInv/src/fdtd/updates.jl:141
# ┌ Warning: decrease maximum spatial sampling (5.00e+00) below 4.32e+00
# └ @ GeoPhyInv /home/pawan/.julia/dev/GeoPhyInv/src/fdtd/stability.jl:38

# %%
# typeof(Data.Array(zeros(2)))
# using CUDA
# CUDA.zeros(5)
Data.Array
# Out:
# CuArray{Float64, N, B} where {N, B}

# %%
Data.Array{1, CUDA.Mem.DeviceBuffer}
# Out:
# CuArray{Float64, 1, CUDA.Mem.DeviceBuffer}

# %%
pa.c.exmedium.mgrid
# Out:
# 2-element Vector{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}}}:
#  500.0:5.0:3600.0
#  3900.0:5.0:13100.0

# %%
srcwav
# tgrid
# Out:
# 1-element Vector{GeoPhyInv.NamedD{Srcs}}:
#  > data with fields [:vx] at 1 source

# %%
GeoPhyInv.update!(pa)
# Out:
# ┌ Warning: Performing scalar indexing on task Task (runnable) @0x000014b5c5ea02b0.
# │ Invocation of getindex resulted in scalar indexing of a GPU array.
# │ This is typically caused by calling an iterating implementation of a method.
# │ Such implementations *do not* execute on the GPU, but very slowly on the CPU,
# │ and therefore are only permitted from the REPL for prototyping purposes.
# │ If you did intend to index this array, annotate the caller with @allowscalar.
# └ @ GPUArrays /home/pawan/.julia/packages/GPUArrays/0vqbc/src/host/indexing.jl:56
# 	modeling supershot 1/1 100%|███████████████████████████| Time: 0:00:11
#  ──────────────────────────────────────────────────────────────────────────
#                                    Time                   Allocations
#                            ──────────────────────   ───────────────────────
#      Tot / % measured:          12.2s / 96.3%           1.95GiB / 98.1%
#
#  Section           ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────────────
#  mod_x_proc!            1    11.6s  98.9%   11.6s   1.91GiB  100%   1.91GiB
#  record data            1   99.0ms  0.85%  99.0ms   6.74MiB  0.34%  6.74MiB
#  initialize!            1   30.1ms  0.26%  30.1ms   64.8KiB  0.00%  64.8KiB
#  stack_grads!           1   30.1μs  0.00%  30.1μs   2.09KiB  0.00%  2.09KiB
#  update gradient        1    160ns  0.00%   160ns     0.00B  0.00%    0.00B
#  ──────────────────────────────────────────────────────────────────────────

# %%
# ENV["GKSwstype"] = "nul";
# if (isdir("viz3D_out") == false)
#     mkdir("viz3D_out")
# else
#     foreach(rm, filter(endswith(".png"), readdir("./viz3D_out", join = true)))
# end;
# loadpath = "./viz3D_out/";
# anim1 = Animation(loadpath, String["slice y"])

# println("Animation directory: $(anim1.dir)")
pmax=maximum([maximum(pa[:snaps][it]) for it in 1:length(tsnaps)])

    anim=@animate for it in 1:length(tsnaps)

    # Visualisation

        f=pa[:snaps,1][it]
        if(length(mgrid)==2)
           heatmap(f,         
            aspect_ratio = 1/3,
            xlims = (1, size(f,2)),
            ylims = (1, size(f,1)),
                yflip=true,
            c = :seismic,
            title = string("snapshot at: ",tsnaps[it]),
            clims = (-pmax, pmax),
        )
        else 
            heatmap(Array(localpart(pa.p)[1].w1[:t][:vx])[1:end, div(ny,2), 1:end],
            aspect_ratio = 1,
            # xlims = (1, nx + 1),
            # ylims = (1, nz),
#                 yflip=true,
            c = :seismic,
            title = "vx",
            clims = (-pmax, pmax),
        )

    end
    

end
# Out:
# Animation("/tmp/jl_aogzbZ", ["000001.png", "000002.png", "000003.png", "000004.png", "000005.png", "000006.png", "000007.png", "000008.png", "000009.png", "000010.png"  …  "000012.png", "000013.png", "000014.png", "000015.png", "000016.png", "000017.png", "000018.png", "000019.png", "000020.png", "000021.png"])

# %%
gif(anim, fps=1)
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/pawan/.julia/dev/GeoPhyInv/src/fdtd/tmp.gif
# └ @ Plots /home/pawan/.julia/packages/Plots/HcxwM/src/animation.jl:114
# Plots.AnimatedGif("/home/pawan/.julia/dev/GeoPhyInv/src/fdtd/tmp.gif")

# %%
typeof(localpart(pa.p)[1].ss[1].snaps)
findall(x->x==321, pa.c.itsnaps)
# Out:
# Int64[]

# %%
maximum([maximum(pa[:snaps][it]) for it in 1:length(tsnaps)])

# size(pa[:snaps,1])
# pa.c.itsnaps
# Out:
# BoundsError: attempt to access 1-element Vector{Matrix{Float64}} at index [2]
#
# Stacktrace:
#   [1] getindex
#     @ ./array.jl:801 [inlined]
#   [2] getindex(n::NamedVector{Matrix{Float64}, Vector{Matrix{Float64}}, Tuple{OrderedDict{String, Int64}}}, I::Int64)
#     @ NamedArrays ~/.julia/packages/NamedArrays/TuJLn/src/index.jl:17
#   [3] getindex(r::Future, args::Int64)
#     @ Distributed /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.6/Distributed/src/remotecall.jl:639
#   [4] (::var"#3#4")(it::Int64)
#     @ Main ./none:0
#   [5] iterate
#     @ ./generator.jl:47 [inlined]
#   [6] collect_to!(dest::Vector{Float64}, itr::Base.Generator{UnitRange{Int64}, var"#3#4"}, offs::Int64, st::Int64)
#     @ Base ./array.jl:724
#   [7] collect_to_with_first!(dest::Vector{Float64}, v1::Float64, itr::Base.Generator{UnitRange{Int64}, var"#3#4"}, st::Int64)
#     @ Base ./array.jl:702
#   [8] collect(itr::Base.Generator{UnitRange{Int64}, var"#3#4"})
#     @ Base ./array.jl:683
#   [9] top-level scope
#     @ In[24]:1
#  [10] eval
#     @ ./boot.jl:360 [inlined]
#  [11] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1094

# %%
# gr()
# pa.c.pml[:x][:a][end-16:end]
heatmap(pa[:data][:vz])
